# %%
import cv2 ###pip install opencv-python
##pip install opencv-contrib-python full package

# %%
from deepface import DeepFace
# Out:
# WARNING:tensorflow:From C:\Users\Poojitha\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
img = cv2.imread('happyboy.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions =DeepFace.analyze(img, enforce_detection=False)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:11<00:00,  2.91s/it]

# %%
predictions
# Out:
# [{'emotion': {'angry': 5.320549556486753e-10,
#    'disgust': 3.0866033626360027e-16,
#    'fear': 4.941062207823588e-11,
#    'happy': 99.99974966049194,
#    'sad': 1.7693620874004168e-09,
#    'surprise': 1.7416534252127913e-11,
#    'neutral': 0.0002534718532842817},
#   'dominant_emotion': 'happy',
#   'region': {'x': 316,
#    'y': 175,
#    'w': 330,
#    'h': 330,
#    'left_eye': (540, 302),
#    'right_eye': (421, 300)},
#   'face_confidence': 0.9,
#   'age': 17,
#   'gender': {'Woman': 33.890172839164734, 'Man': 66.10982418060303},
#   'dominant_gender': 'Man',
#   'race': {'asian': 17.926204204559326,
#    'indian': 0.8829248137772083,
#    'black': 0.10636220686137676,
#    'white': 48.874714970588684,
#    'middle eastern': 4.396795108914375,
#    'latino hispanic': 27.812999486923218},
#   'dominant_race': 'white'}]

# %%
type(predictions)
# Out:
# list

# %%
predictions[0]['dominant_emotion']
# Out:
# 'happy'

# %% [markdown]
# # we are trying to draw a rectangle on face

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.1,4)
for(x, y, w, h)in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0),2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,
            predictions[0]['dominant_emotion'],
            (0,50),
            font, 1,
            (0, 0, 255),
            2,
            cv2.LINE_4) ;

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('sad.jpeg')

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions =DeepFace.analyze(img, enforce_detection=False)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  3.19it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 2.1529123187065125,
#    'disgust': 0.00022389094738173299,
#    'fear': 7.644131779670715,
#    'happy': 7.206704708551115e-05,
#    'sad': 86.75902485847473,
#    'surprise': 9.656732800067402e-05,
#    'neutral': 3.443540632724762},
#   'dominant_emotion': 'sad',
#   'region': {'x': 201,
#    'y': 14,
#    'w': 237,
#    'h': 237,
#    'left_eye': (356, 104),
#    'right_eye': (273, 110)},
#   'face_confidence': 0.9,
#   'age': 30,
#   'gender': {'Woman': 99.16083216667175, 'Man': 0.8391602896153927},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 99.40508600503719,
#    'indian': 0.21589909570062732,
#    'black': 9.04838824953474e-05,
#    'white': 0.03394089492244392,
#    'middle eastern': 6.202601895432706e-05,
#    'latino hispanic': 0.3449283280180888},
#   'dominant_race': 'asian'}]

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.1,4)
for(x, y, w, h)in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0),2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,
            predictions[0]['dominant_emotion'],
            (0,50),
            font, 1,
            (0, 0, 255),
            2,
            cv2.LINE_4) ;

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('surprise.jpeg')

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions =DeepFace.analyze(img, enforce_detection=False)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.53it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 1.9109581723617384e-08,
#    'disgust': 1.1173408315023684e-15,
#    'fear': 0.00017403441361740928,
#    'happy': 3.953066165772316e-08,
#    'sad': 1.5655210808972453e-11,
#    'surprise': 99.99982714651985,
#    'neutral': 4.39892696881109e-19},
#   'dominant_emotion': 'surprise',
#   'region': {'x': 87,
#    'y': 31,
#    'w': 96,
#    'h': 96,
#    'left_eye': (150, 72),
#    'right_eye': (117, 70)},
#   'face_confidence': 0.9,
#   'age': 20,
#   'gender': {'Woman': 0.3117539919912815, 'Man': 99.6882438659668},
#   'dominant_gender': 'Man',
#   'race': {'asian': 14.602236449718475,
#    'indian': 1.4094559475779533,
#    'black': 0.31938920728862286,
#    'white': 29.956167936325073,
#    'middle eastern': 4.967821016907692,
#    'latino hispanic': 48.74493181705475},
#   'dominant_race': 'latino hispanic'}]

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.1,4)
for(x, y, w, h)in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0),2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,
            predictions[0]['dominant_emotion'],
            (0,50),
            font, 1,
            (0, 0, 255),
            2,
            cv2.LINE_4) ;

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # real time video demo for face emotion recognition

# %%
import cv2
from deepface import DeepFace
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
cap = cv2.VideoCapture(0)
#check if webcam is opened correctly
if not cap.isOpened():
    cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("cannot open webcam")
while True:
    ret,frame = cap.read()
    
    result = DeepFace.analyze(frame, actions = ['emotion'],enforce_detection=False)
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    #print(facecascade.empty())
    faces = faceCascade.detectMultiScale(gray,1.1,4)
    
    #draw a rectangle around faces
    for(x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

    font = cv2.FONT_HERSHEY_SIMPLEX
    
    #use puttext() method for
    #inserting text on video
    cv2.putText(frame,
                result[0]['dominant_emotion'],
                (50,50),
                font,3,
                (0,0,255),
                2,
                cv2.LINE_4)
    cv2.imshow('original video',frame)

    if cv2.waitKey(2) & 0xFF == ord('q'):
       break

cap.release()
cv2.destroyAllWindows()
